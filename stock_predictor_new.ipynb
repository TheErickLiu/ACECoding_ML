# %%
import pandas as pd

def get_historical_data_from_csv(filepath):
    df = pd.read_csv(filepath)
    cols = ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
    for c in cols:
        df[c] = pd.to_numeric(df[c], errors='coerce')

    return df

# %%
import numpy as np

df = get_historical_data_from_csv("StockHistoricalData/TSLA.csv")
print(df.head())
# Out:
#            Date    Open    High     Low   Close  Adj Close  Volume
# 0  Nov 26, 2025  423.95  426.94  416.89  426.58     426.58     NaN
# 1  Nov 25, 2025  414.42  420.48  405.95  419.40     419.40     NaN
# 2  Nov 24, 2025  402.17  421.72  401.09  417.78     417.78     NaN
# 3  Nov 21, 2025  402.32  402.80  383.76  391.09     391.09     NaN
# 4  Nov 20, 2025  414.63  428.94  394.74  395.23     395.23     NaN

# %%
data = get_historical_data_from_csv("StockHistoricalData/TSLA.csv")
print("\n")
print("Open   --- mean :", np.mean(data['Open']),  "  \t Std: ", np.std(data['Open']),  "  \t Max: ", np.max(data['Open']),  "  \t Min: ", np.min(data['Open']))
print("High   --- mean :", np.mean(data['High']),  "  \t Std: ", np.std(data['High']),  "  \t Max: ", np.max(data['High']),  "  \t Min: ", np.min(data['High']))
print("Low    --- mean :", np.mean(data['Low']),   "  \t Std: ", np.std(data['Low']),   "  \t Max: ", np.max(data['Low']),   "  \t Min: ", np.min(data['Low']))
print("Close  --- mean :", np.mean(data['Close']), "  \t Std: ", np.std(data['Close']), "  \t Max: ", np.max(data['Close']), "  \t Min: ", np.min(data['Close']))
print("Adj Close  --- mean :", np.mean(data['Adj Close']), "  \t Std: ", np.std(data['Adj Close']), "  \t Max: ", np.max(data['Adj Close']), "  \t Min: ", np.min(data['Adj Close']))
print("Volume --- mean :", np.mean(data['Volume']),"  \t Std: ", np.std(data['Volume']),"  \t Max: ", np.max(data['Volume']),"  \t Min: ", np.min(data['Volume']))
# Out:
# Open   --- mean : 261.0563535031847   	 Std:  72.88701655251086   	 Max:  475.9   	 Min:  103.0
# High   --- mean : 266.82969745222925   	 Std:  74.40658643456754   	 Max:  488.54   	 Min:  111.75
# Low    --- mean : 254.8569187898089   	 Std:  70.93118246020995   	 Max:  457.51   	 Min:  101.81
# Close  --- mean : 260.96174363057327   	 Std:  72.68177188974552   	 Max:  479.86   	 Min:  108.1
# Adj Close  --- mean : 260.96174363057327   	 Std:  72.68177188974552   	 Max:  479.86   	 Min:  108.1
# Volume --- mean : nan   	 Std:  nan   	 Max:  nan   	 Min:  nan

# %%
print(data.head())
print(data.tail())
# Out:
#            Date    Open    High     Low   Close  Adj Close  Volume
# 0  Nov 26, 2025  423.95  426.94  416.89  426.58     426.58     NaN
# 1  Nov 25, 2025  414.42  420.48  405.95  419.40     419.40     NaN
# 2  Nov 24, 2025  402.17  421.72  401.09  417.78     417.78     NaN
# 3  Nov 21, 2025  402.32  402.80  383.76  391.09     391.09     NaN
# 4  Nov 20, 2025  414.63  428.94  394.74  395.23     395.23     NaN
#               Date    Open    High     Low   Close  Adj Close  Volume
# 1252   Dec 3, 2020  196.67  199.66  194.14  197.79     197.79     NaN
# 1253   Dec 2, 2020  185.48  190.51  180.40  189.61     189.61     NaN
# 1254   Dec 1, 2020  199.20  199.28  190.68  194.92     194.92     NaN
# 1255  Nov 30, 2020  200.74  202.60  184.84  189.20     189.20     NaN
# 1256  Nov 27, 2020  193.72  199.59  192.82  195.25     195.25     NaN

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your CSV
data = get_historical_data_from_csv("StockHistoricalData/TSLA.csv")

# Convert Date to datetime and index it
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)

# Plot Date vs Close
plt.figure(figsize=(12, 6))
plt.plot(data.index, data['Close'])

plt.title("TSLA Closing Price Over Time")
plt.xlabel("Date")
plt.ylabel("Close Price (USD)")
plt.grid(True)

plt.show()

# %%
import math
import pandas as pd
import numpy as np
from IPython.display import display

from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.models import Sequential
from keras.metrics import mean_squared_error
from sklearn.model_selection import StratifiedKFold

# Your imports
import lstm, time
import visualize as vs
import stock_data as sd
import LinearRegressionModel

# Load TSLA data using your new CSV function
stocks = get_historical_data_from_csv("StockHistoricalData/TSLA.csv")

# Convert date and index it
stocks['Date'] = pd.to_datetime(stocks['Date'])
stocks.set_index('Date', inplace=True)

# Keep ONLY Open and Close columns
stocks_data = stocks[['Open', 'Close']]

# Display the cleaned dataframe
display(stocks_data.head())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 6
#       3 import numpy as np
#       4 from IPython.display import display
# ----> 6 from keras.layers.core import Dense, Activation, Dropout
#       7 from keras.layers.recurrent import LSTM
#       8 from keras.models import Sequential
#
# ModuleNotFoundError: No module named 'keras.layers.core'
